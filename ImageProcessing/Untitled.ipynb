# %%
#utf-8

# %%
import pytesseract as pytess
from PIL import Image

# %%
image = Image.open('standard.png')

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=320x271 at 0x599D710>

# %%
pytess.image_to_string?

# %%
code = pytess.image_to_string(image,lang='chi')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-28-0151a5213e37> in <module>()
# ----> 1 code = pytess.image_to_string(image,lang='chi')
#
# D:\Anaconda\lib\site-packages\pytesseract\pytesseract.py in image_to_string(image, lang, boxes, config)
#     165         f = open(output_file_name)
#     166         try:
# --> 167             return f.read().strip()
#     168         finally:
#     169             f.close()
#
# UnicodeDecodeError: 'gbk' codec can't decode byte 0x94 in position 2: illegal multibyte sequence

# %%
def test(a:str):
    print(a)

# %%
test([1,2])
# Out:
# [1, 2]
