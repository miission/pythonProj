# %%
#coding=utf-8

# %%
import urllib.request
import chardet
from bs4 import BeautifulSoup

# %%
url="https://item.jd.com/3882469.html#comment" # 要爬取的网络地址
JD_Item_Content=urllib.request.urlopen(url).read()  # 将网页源代码赋予menuCode

# %%
JD_Item_Content
# Out:
# <!-- shouji -->
# <!DOCTYPE HTML>
#
# <html lang="zh-CN">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>【华为荣耀8 青春版】荣耀8青春版 全网通 标配版 3GB+32GB 流光金【行情 报价 价格 评测】-京东</title>
# <meta content="HUAWEI荣耀8 青春版,华为荣耀8 青春版,华为荣耀8 青春版报价,HUAWEI荣耀8 青春版报价" name="keywords"/>
# <meta content="【华为荣耀8 青春版】京东JD.COM提供华为荣耀8 青春版正品行货，并包括HUAWEI荣耀8 青春版网购指南，以及华为荣耀8 青春版图片、荣耀8 青春版参数、荣耀8 青春版评论、荣耀8 青春版心得、荣耀8 青春版技巧等信息，网购华为荣耀8 青春版上京东,放心又轻松" name="description"/>
# <meta content="telephone=no" name="format-detection">
# <meta content="format=xhtml; url=//item.m.jd.com/product/3882469.html" http-equiv="mobile-agent">
# <meta content="format=html5; url=//item.m.jd.com/product/3882469.html" http-equiv="mobile-agent">
# <meta content="IE=Edge" http-equiv="X-UA-Compatible">
# <link href="//item.jd.com/3882469.html" rel="canonical"/>
# <link href="//misc.360buyimg.com" rel="dns-prefetch"/>
# <link href="//static.360buyimg.com" rel="dns-prefetch"/>
# ...

# %%
JD_Item_Content=BeautifulSoup(JD_Item_Content,'html.parser')  # 使用html解析器进行解析

# %%
menu=JD_Item_Content.find('div',{'class':'m m-content comment'})

# %%
menu
# Out:
# <div class="m m-content comment" id="comment">
# <div class="mt">
# <h3>商品评价</h3>
# </div>
# <div class="mc">
# <div class="J-i-comment i-comment clearfix"></div>
# <div class="J-comments-list comments-list ETab">
# <div class="tab-main small">
# <ul>
# <li class="current" clstag="shangpin|keycount|product|allpingjia_1" data-tab="trigger"><a href="javascript:;">全部评论<em>()</em></a></li>
# <li clstag="shangpin|keycount|product|shaipic" data-tab="trigger"><a href="javascript:;">晒图<em>()</em></a></li>
# <li clstag="shangpin|keycount|product|haoping_1" data-tab="trigger"><a href="javascript:;">好评<em>()</em></a></li>
# <li clstag="shangpin|keycount|product|zhongping_1" data-tab="trigger"><a href="javascript:;">中评<em>()</em></a></li>
# <li clstag="shangpin|keycount|product|chaping_1" data-tab="trigger"><a href="javascript:;">差评<em>()</em></a></li>
# <li class="try-report-btn" clstag="shangpin|keycount|product|sybg-bq" style="display:none;"><a href="#try-report">试用报告<em>()</em></a></li>
# ...

# %%
menu.find('div',{'class':'tag-list'})

# %%
menu.find('li',{'class':'current'}).text
# Out:
# '全部评论()'

# %%
bookName=soup.h1.string # 找到了书名
f=open('D://'+bookName+'.txt','a',encoding='utf8')

# %%
bookMenu=[] # 章节list
bookMenuUrl=[] # 章节url的list
for i in range(1,len(soup2.contents)-1): # 依次爬取书的章节
  bookMenu.append(soup2.contents[i].string)
  bookMenuUrl.append(soup2.contents[i].a['href'])
urlBegin="http://www.shicimingju.com" # 解决url为本地的问题
