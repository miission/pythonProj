# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Dec 23 11:21:07 2016

@author: changlue.she
"""

from urllib  import urlopen
from bs4 import BeautifulSoup
from crawler.downloadPage import JDpage
'''get the first class categories'''
html  = urlopen('https://www.jd.com/')
bsObj = BeautifulSoup(html.read()) 
firstClassContents =  bsObj.find('ul',{'class':'JS_navCtn cate_menu'}).findAll('li',{'class':'cate_menu_item'})
firstClassList = [line.text for line in firstClassContents]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-37-55e5e61e667a> in <module>()
#       7
#       8 from urllib  import urlopen
# ----> 9 from bs4 import BeautifulSoup
#      10 from crawler.downloadPage import JDpage
#      11 '''get the first class categories'''
#
# ImportError: No module named bs4

# %%
import urllib

# %%
def getHtml(url):
    page = urllib.urlopen(url)  #urllib.urlopen()方法用于打开一个URL地址
    html = page.read() #read()方法用于读取URL上的数据
    return html

# %%
bsObj = getHtml('https://www.jd.com/')

# %%
bsObj
# Out:
# '<!DOCTYPE html>\n<html>\n\n<head>\n  <meta charset="UTF-8">\n  <title>\xe4\xba\xac\xe4\xb8\x9c(JD.COM)-\xe6\xad\xa3\xe5\x93\x81\xe4\xbd\x8e\xe4\xbb\xb7\xe3\x80\x81\xe5\x93\x81\xe8\xb4\xa8\xe4\xbf\x9d\xe9\x9a\x9c\xe3\x80\x81\xe9\x85\x8d\xe9\x80\x81\xe5\x8f\x8a\xe6\x97\xb6\xe3\x80\x81\xe8\xbd\xbb\xe6\x9d\xbe\xe8\xb4\xad\xe7\x89\xa9\xef\xbc\x81</title>\n  <meta name="description" content="\xe4\xba\xac\xe4\xb8\x9cJD.COM-\xe4\xb8\x93\xe4\xb8\x9a\xe7\x9a\x84\xe7\xbb\xbc\xe5\x90\x88\xe7\xbd\x91\xe4\xb8\x8a\xe8\xb4\xad\xe7\x89\xa9\xe5\x95\x86\xe5\x9f\x8e,.!" />\n  <meta name="Keywords" content="\xe7\xbd\x91\xe4\xb8\x8a\xe8\xb4\xad\xe7\x89\xa9,\xe7\xbd\x91\xe4\xb8\x8a\xe5\x95\x86\xe5\x9f\x8e,\xe6\x89\x8b\xe6\x9c\xba,\xe7\xac\x94\xe8\xae\xb0\xe6\x9c\xac,\xe7\x94\xb5\xe8\x84\x91,MP3,CD,VCD,DV,\xe7\x9b\xb8\xe6\x9c\xba,\xe6\x95\xb0\xe7\xa0\x81,\xe9\x85\x8d\xe4\xbb\xb6,\xe6\x89\x8b\xe8\xa1\xa8,\xe5\xad\x98\xe5\x82\xa8\xe5\x8d\xa1,\xe4\xba\xac\xe4\xb8\x9c" />\n\n  <script type="text/javascript">\n    window.sourceVersion = {"focus":"0f821131b5189853e9c83c2c1470235a","coupons":"1329fd184f20aae19a56ccce463f5998","basic_1":"db84b819b55c919f460795b87aca5467","basic_2":"8c04356bbce404ca823510d895b20145","basic_3":"f9271809f1a3e04e12758c84772db96a","basic_4":"b00b64c60129dd2e55ed29b71af0469e","basic_5":"6718c83b899fd5141208239178b9cb0e","basic_6":"6329c491ca10c75673ff196ef7add7aa","basic_7":"b3d8ff09c7c91235737f33f1ea8e2e43","basic_8":"2871b58b4b5672d86cd47904c9528aa4","entry":"10fd22ea69f9f62721daa1529ae140ed","special_1":"92624a3c7cdd586d9a08f46274d56f54","special_2":"cca7afcd1f62bbcee56607026732a00e","banner_1":"a595e4ba282781b71d618a0387b3fd6c","banner_2":"8b09de5145f29254fabd8344211205c6","banner_3":"9c506f257077cb6a5b511d405219fecb","banner_4":"27ba8d39c010d0bdf64b430f87ceedba","aggr":"a358b74a2861f2c1c72265626da4b211","enjoy":"a07a697b63fd9bf870dc6668a5e0021f","npeople":"c949915e90bcdc935ffac4f67d8a3f22"};\n  </script>\n\n\n<script type="text/javascript">\n    window.pageConfig = { compatible: true, preload: false, navId: "jdhome2016", timestamp: 1495769589000 , leftCateABtestSwitch:0, isEnablePDBP: 0, surveyLink : \'//surveys.jd.com/index.php?r=survey/index/sid/889711/newtest/Y/lang/zh-Hans\', surveyTitle : \'\xe8\xb0\x83\xe6\x9f\xa5\xe9\x97\xae\xe5\x8d\xb7\', awardsLink : \'//surveys.jd.com/index.php?r=survey/index/sid/218364/lang/zh-Hans\', awardsTitle : \'\xe6\x9c\x89\xe5\xa5\x96\xe8\xb0\x83\xe6\x9f\xa5\' };\n</script>\n<!--[if lte IE 6]>\n      <script src="//misc.360buyimg.com/mtd/pc/index/home/ie6tip.min.js"></script>\n  <![endif]-->\n  <link rel="dns-prefetch" href="//static.360buyimg.com" />\n  <link rel="dns-prefetch" href="//misc.360buyimg.com" />\n  <link rel="dns-prefetch" href="//img10.360buyimg.com" />\n  <link rel="dns-prefetch" href="//img11.360buyimg.com" />\n  <link rel="dns-prefetch" href="//img12.360buyimg.com" />\n  <link rel="dns-prefetch" href="//img13.360buyimg.com" />\n  <link rel="dns-prefetch" href="//img14.360buyimg.com" />\n  <link rel="dns-prefetch" href="//img30.360buyimg.com" />\n  <link rel="dns-prefetch" href="//f.3.cn" />\n  <link rel="dns-prefetch" href="//d.jd.com" />\n  <link rel="dns-prefetch" href="//ai.jd.com" />\n  <link rel="dns-prefetch" href="//ch.jd.co ...

# %%
firstClassContents =  bsObj.find('ul',{'class':'JS_navCtn cate_menu'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-17398f1f641a> in <module>()
# ----> 1 firstClassContents =  bsObj.find('ul',{'class':'JS_navCtn cate_menu'})
#
# TypeError: slice indices must be integers or None or have an __index__ method
